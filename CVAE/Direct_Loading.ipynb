# %% [markdown]
# <a href="https://colab.research.google.com/github/atharvakale31/DL_auto_encoders/blob/master/CVAE_on_Retail_(loading_images_directly).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Convolutional Variational Autoencoder

# %% [markdown]
# **Please make a copy to make edits**

# %% [markdown]
# ## Setup

# %%
# !pip install git+https://github.com/tensorflow/docs
# Out:
# Collecting git+https://github.com/tensorflow/docs
#   Cloning https://github.com/tensorflow/docs to /tmp/pip-req-build-cwq8ltbc
#   Running command git clone -q https://github.com/tensorflow/docs /tmp/pip-req-build-cwq8ltbc
# Requirement already satisfied: astor in /usr/local/lib/python3.7/dist-packages (from tensorflow-docs===0.0.0b993e77054dcafbd8b0da0a9d6f9ad7c10975901-) (0.8.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from tensorflow-docs===0.0.0b993e77054dcafbd8b0da0a9d6f9ad7c10975901-) (0.12.0)
# Requirement already satisfied: protobuf>=3.14 in /usr/local/lib/python3.7/dist-packages (from tensorflow-docs===0.0.0b993e77054dcafbd8b0da0a9d6f9ad7c10975901-) (3.17.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from tensorflow-docs===0.0.0b993e77054dcafbd8b0da0a9d6f9ad7c10975901-) (3.13)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.14->tensorflow-docs===0.0.0b993e77054dcafbd8b0da0a9d6f9ad7c10975901-) (1.15.0)
# Building wheels for collected packages: tensorflow-docs
#   Building wheel for tensorflow-docs (setup.py) ... done
#   Created wheel for tensorflow-docs: filename=tensorflow_docs-0.0.0b993e77054dcafbd8b0da0a9d6f9ad7c10975901_-py3-none-any.whl size=154388 sha256=9ecd17a18ed7caca4a970ae626c76c4c148dba6c0e964c966f77e414dc05a5dc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-r91dqmr5/wheels/cc/c4/d8/5341e93b6376c5c929c49469fce21155eb69cef1a4da4ce32c
#   WARNING: Built wheel for tensorflow-docs is invalid: Metadata 1.2 mandates PEP 440 version, but '0.0.0b993e77054dcafbd8b0da0a9d6f9ad7c10975901-' is not
# Failed to build tensorflow-docs
# Installing collected packages: tensorflow-docs
#     Running setup.py install for tensorflow-docs ... done
#   DEPRECATION: tensorflow-docs was installed using the legacy 'setup.py install' method, because a wheel could not be built for it. A possible replacement is to fix the wheel build issue reported above. You can find discussion regarding this at https://github.com/pypa/pip/issues/8368.
# Successfully installed tensorflow-docs-0.0.0b993e77054dcafbd8b0da0a9d6f9ad7c10975901-

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !cp -r "/content/drive/MyDrive/augmented_images" "/content/"

# %%
from IPython import display

import glob
import imageio
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
import tensorflow_probability as tfp
import time
import pathlib
import cv2
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers

# %%
import zipfile  # unziping 
import glob  # finding image paths
import numpy as np  # creating numpy arrays
from skimage.io import imread  # reading images
from skimage.transform import resize  # resizing images

# %%
dataset_url = "http://aisdatasets.informatik.uni-freiburg.de/freiburg_groceries_dataset/freiburg_groceries_dataset.tar.gz"
data_dir = tf.keras.utils.get_file('images', origin=dataset_url,  cache_dir='.', untar=True)
# Out:
# Downloading data from http://aisdatasets.informatik.uni-freiburg.de/freiburg_groceries_dataset/freiburg_groceries_dataset.tar.gz
# 541564928/541562880 [==============================] - 29s 0us/step

# %%
data_dir = pathlib.Path(data_dir)
data_dir
# Out:
# PosixPath('datasets/images')

# %%
# img_list = sorted(glob.glob('/content/dog/*.jpg'))
img_list = sorted(glob.glob('/content/datasets/images/*/*.png'))

# %%
img_list
# Out:
# ['/content/datasets/images/BEANS/BEANS0000.png',
#  '/content/datasets/images/BEANS/BEANS0001.png',
#  '/content/datasets/images/BEANS/BEANS0002.png',
#  '/content/datasets/images/BEANS/BEANS0003.png',
#  '/content/datasets/images/BEANS/BEANS0004.png',
#  '/content/datasets/images/BEANS/BEANS0005.png',
#  '/content/datasets/images/BEANS/BEANS0006.png',
#  '/content/datasets/images/BEANS/BEANS0007.png',
#  '/content/datasets/images/BEANS/BEANS0008.png',
#  '/content/datasets/images/BEANS/BEANS0009.png',
#  '/content/datasets/images/BEANS/BEANS0010.png',
#  '/content/datasets/images/BEANS/BEANS0011.png',
#  '/content/datasets/images/BEANS/BEANS0012.png',
#  '/content/datasets/images/BEANS/BEANS0013.png',
#  '/content/datasets/images/BEANS/BEANS0014.png',
#  '/content/datasets/images/BEANS/BEANS0015.png',
#  '/content/datasets/images/BEANS/BEANS0016.png',
#  '/content/datasets/images/BEANS/BEANS0017.png',
#  '/content/datasets/images/BEANS/BEANS0018.png',
#  '/content/datasets/images/BEANS/BEANS0019.png',
#  '/content/datasets/images/BEANS/BEANS0020.png',
#  '/content/datasets/images/BEANS/BEANS0021.png',
#  '/content/datasets/images/BEANS/BEANS0022.png',
#  '/content/datasets/images/BEANS/BEANS0023.png',
#  '/content/datasets/images/BEANS/BEANS0024.png',
#  '/content/datasets/images/BEANS/BEANS0025.png',
#  '/content/datasets/images/BEANS/BEANS0026.png',
#  '/content/datasets/images/BEANS/BEANS0027.png',
#  '/content/datasets/images/BEANS/BEANS0028.png',
#  '/content/datasets/images/BEANS/BEANS0029.png',
#  '/content/datasets/images/BEANS/BEANS0030.png',
#  '/content/datasets/images/BEANS/BEANS0031.png',
#  '/content/datasets/images/BEANS/BEANS0032.png',
#  '/content/datasets/images/BEANS/BEANS0033.png',
#  '/content/datasets/images/BEANS/BEANS0034.png',
#  '/content/datasets/images/BEANS/BEANS0035.png',
#  '/content/datasets/images/BEANS/BEANS0036.png',
#  '/content/datasets/images/BEANS/BEANS0037.png',
#  '/content/datasets/images/BEANS/BEANS0038.png',
#  '/content/datasets/images/BEANS/BEANS0039.png',
#  '/content/datasets/images/BEANS/BEANS0040.png',
#  '/content/datasets/images/BEANS/BEANS0041.png',
#  '/content/datasets/images/BEANS/BEANS0042.png',
#  '/content/datasets/images/BEANS/BEANS0043.png',
#  '/content/datasets/images/BEANS/BEANS0044.png',
#  '/content/datasets/images/BEANS/BEANS0045.png',
#  '/content/datasets/images/BEANS/BEANS0046.png',
#  '/content/datasets/images/BEANS/BEANS0047.png',
#  '/content/datasets/images/BEANS/BEANS0048.png',
#  '/content/datasets/images/BEANS/BEANS0049.png',
#  '/content/datasets/images/BEANS/BEANS0050.png',
#  '/content/datasets/images/BEANS/BEANS0051.png',
#  '/content/datasets/images/BEANS/BEANS0052.png',
#  '/content/datasets/images/BEANS/BEANS0053.png',
#  '/content/datasets/images/BEANS/BEANS0054.png',
#  '/content/datasets/images/BEANS/BEANS0055.png',
#  '/content/datasets/images/BEANS/BEANS0056.png',
#  '/content/datasets/images/BEANS/BEANS0057.png',
#  '/content/datasets/images/BEANS/BEANS0058.png',
#  '/content/datasets/images/BEANS/BEANS0059.png',
#  '/content/datasets/images/BEANS/BEANS0060.png',
#  '/content/datasets/images/BEANS/BEANS0061.png',
#  '/content/datasets/images/BEANS/BEANS0062.png',
#  '/content/datasets/images/BEANS/BEANS0063.png',
#  '/content/datasets/images/BEANS/BEANS0064.png',
#  '/content/datasets/images/BEANS/BEANS0065.png',
#  '/content/datasets/images/BEANS/BEANS0066.png',
#  '/content/datasets/images/BEANS/BEANS0067.png',
#  '/content/datasets/images/BEANS/BEANS0068.png',
#  '/content/datasets/images/BEANS/BEANS0069.png',
#  '/content/datasets/images/BEANS/BEANS0070.png',
#  '/content/datasets/images/BEANS/BEANS0071.png',
#  '/content/datasets/images/BEANS/BEANS0072.png',
#  '/content/datasets/images/BEANS/BEANS0073.png',
#  '/content/datasets/images/BEANS/BEANS0074.png',
#  '/content/datasets/images/BEANS/BEANS0075.png',
#  '/content/datasets/images/BEANS/BEANS0076.png',
#  '/content/datasets/images/BEANS/BEANS0077.png',
#  '/content/datasets/images/BEANS/BEANS0078.png',
#  '/content/datasets/images/BEANS/BEANS0079.png',
#  '/content/datasets/images/BEANS/BEANS0080.png',
#  '/content/datasets/images/BEANS/BEANS0081.png',
#  '/content/datasets/images/BEANS/BEANS0082.png',
#  '/content/datasets/images/BEANS/BEANS0083.png',
#  '/content/datasets/images/BEANS/BEANS0084.png',
#  '/content/datasets/images/BEANS/BEANS0085.png',
#  '/content/datasets/images/BEANS/BEANS0086.png',
#  '/content/datasets/images/BEANS/BEANS0087.png',
#  '/content/datasets/images/BEANS/BEANS0088.png',
#  '/content/datasets/images/BEANS/BEANS0089.png',
#  '/content/datasets/images/BEANS/BEANS0090.png',
#  '/content/datasets/images/BEANS/BEANS0091.png',
#  '/content/datasets/images/BEANS/BEANS0092.png',
#  '/content/datasets/images/BEANS/BEANS0093.png',
#  '/content/datasets/images/BEANS/BEANS0094.png',
#  '/content/datasets/images/BEANS/BEANS0095.png',
#  '/content/datasets/images/BEANS/BEANS0096.png',
#  '/content/datasets/images/BEANS/BEANS0097.png',
#  '/content/datasets/images/BEANS/BEANS0098.png',
#  '/content/datasets/images/BEANS/BEANS0099.png',
#  '/content/datasets/images/BEANS/BEANS0100.png',
#  '/content/datasets/images/BEANS/BEANS0101.png',
#  '/content/datasets/images/BEANS/BEANS0102.png',
#  '/content/datasets/images/BEANS/BEANS0103.png',
#  '/content/datasets/images/BEANS/BEANS0104.png',
#  '/content/datasets/images/BEANS/BEANS0105.png',
#  '/content/datasets/images/BEANS/BEANS0106.png',
#  '/content/datasets/images/BEANS/BEANS0107.png',
#  '/content/datasets/images/BEANS/BEANS0108.png',
#  '/content/datasets/images/BEANS/BEANS0109.png',
#  '/content/datasets/images/BEANS/BEANS0110.png',
#  '/content/datasets/images/BEANS/BEANS0111.png',
#  '/content/datasets/images/BEANS/BEANS0112.png',
#  '/content/datasets/images/BEANS/BEANS0113.png',
#  '/content/datasets/images/BEANS/BEANS0114.png',
#  '/content/datasets/images/BEANS/BEANS0115.png',
#  '/content/datasets/images/BEANS/BEANS0116.png',
#  '/content/datasets/images/BEANS/BEANS0117.png',
#  '/content/datasets/images/BEANS/BEANS0118.png',
#  '/content/datasets/images/BEANS/BEANS0119.png',
#  '/content/datasets/images/BEANS/BEANS0120.png',
#  '/content/datasets/images/BEANS/BEANS0121.png',
#  '/content/datasets/images/BEANS/BEANS0122.png',
#  '/content/datasets/images/BEANS/BEANS0123.png',
#  '/content/datasets/images/BEANS/BEANS0124.png',
#  '/content/datasets/images/BEANS/BEANS0125.png',
#  '/content/datasets/images/BEANS/BEANS0126.png',
#  '/content/datasets/images/BEANS/BEANS0127.png',
#  '/content/datasets/images/BEANS/BEANS0128.png',
#  '/content/datasets/images/BEANS/BEANS0129.png',
#  '/content/datasets/images/BEANS/BEANS0130.png',
#  '/content/datasets/images/BEANS/BEANS0131.png',
#  '/content/datasets/images/BEANS/BEANS0132.png',
#  '/content/datasets/images/BEANS/BEANS0133.png',
#  '/content/datasets/images/BEANS/BEANS0134.png',
#  '/content/datasets/images/BEANS/BEANS0135.png',
#  '/content/datasets/images/CAKE/CAKE0000.png',
#  '/content/datasets/images/CAKE/CAKE0001.png',
#  '/content/datasets/images/CAKE/CAKE0002.png',
#  '/content/datasets/images/CAKE/CAKE0003.png',
#  '/content/datasets/images/CAKE/CAKE0004.png',
#  '/content/datasets/images/CAKE/CAKE0005.png',
#  '/content/datasets/images/CAKE/CAKE0006.png',
#  '/content/datasets/images/CAKE/CAKE0007.png',
#  '/content/datasets/images/CAKE/CAKE0008.png',
#  '/content/datasets/images/CAKE/CAKE0009.png',
#  '/content/datasets/images/CAKE/CAKE0010.png',
#  '/content/datasets/images/CAKE/CAKE0011.png',
#  '/content/datasets/images/CAKE/CAKE0012.png',
#  '/content/datasets/images/CAKE/CAKE0013.png',
#  '/content/datasets/images/CAKE/CAKE0014.png',
#  '/content/datasets/images/CAKE/CAKE0015.png',
#  '/content/datasets/images/CAKE/CAKE0016.png',
#  '/content/datasets/images/CAKE/CAKE0017.png',
#  '/content/datasets/images/CAKE/CAKE0018.png',
#  '/content/datasets/images/CAKE/CAKE0019.png',
#  '/content/datasets/images/CAKE/CAKE0020.png',
#  '/content/datasets/images/CAKE/CAKE0021.png',
#  '/content/datasets/images/CAKE/CAKE0022.png',
#  '/content/datasets/images/CAKE/CAKE0023.png',
#  '/content/datasets/images/CAKE/CAKE0024.png',
#  '/content/datasets/images/CAKE/CAKE0025.png',
#  '/content/datasets/images/CAKE/CAKE0026.png',
#  '/content/datasets/images/CAKE/CAKE0027.png',
#  '/content/datasets/images/CAKE/CAKE0028.png',
#  '/content/datasets/images/CAKE/CAKE0029.png',
#  '/content/datasets/images/CAKE/CAKE0030.png',
#  '/content/datasets/images/CAKE/CAKE0031.png',
#  '/content/datasets/images/CAKE/CAKE0032.png',
#  '/content/datasets/images/CAKE/CAKE0033.png',
#  '/content/datasets/images/CAKE/CAKE0034.png',
#  '/content/datasets/images/CAKE/CAKE0035.png',
#  '/content/datasets/images/CAKE/CAKE0036.png',
#  '/content/datasets/images/CAKE/CAKE0037.png',
#  '/content/datasets/images/CAKE/CAKE0038.png',
#  '/content/datasets/images/CAKE/CAKE0039.png',
#  '/content/datasets/images/CAKE/CAKE0040.png',
#  '/content/datasets/images/CAKE/CAKE0041.png',
#  '/content/datasets/images/CAKE/CAKE0042.png',
#  '/content/datasets/images/CAKE/CAKE0043.png',
#  '/content/datasets/images/CAKE/CAKE0044.png',
#  '/content/datasets/images/CAKE/CAKE0045.png',
#  '/content/datasets/images/CAKE/CAKE0046.png',
#  '/content/datasets/images/CAKE/CAKE0047.png',
#  '/content/datasets/images/CAKE/CAKE0048.png',
#  '/content/datasets/images/CAKE/CAKE0049.png',
#  '/content/datasets/images/CAKE/CAKE0050.png',
#  '/content/datasets/images/CAKE/CAKE0051.png',
#  '/content/datasets/images/CAKE/CAKE0052.png',
#  '/content/datasets/images/CAKE/CAKE0053.png',
#  '/content/datasets/images/CAKE/CAKE0054.png',
#  '/content/datasets/images/CAKE/CAKE0055.png',
#  '/content/datasets/images/CAKE/CAKE0056.png',
#  '/content/datasets/images/CAKE/CAKE0057.png',
#  '/content/datasets/images/CAKE/CAKE0058.png',
#  '/content/datasets/images/CAKE/CAKE0059.png',
#  '/content/datasets/images/CAKE/CAKE0060.png',
#  '/content/datasets/images/CAKE/CAKE0061.png',
#  '/content/datasets/images/CAKE/CAKE0062.png',
#  '/content/datasets/images/CAKE/CAKE0063.png',
#  '/content/datasets/images/CAKE/CAKE0064.png',
#  '/content/datasets/images/CAKE/CAKE0065.png',
#  '/content/datasets/images/CAKE/CAKE0066.png',
#  '/content/datasets/images/CAKE/CAKE0067.png',
#  '/content/datasets/images/CAKE/CAKE0068.png',
#  '/content/datasets/images/CAKE/CAKE0069.png',
#  '/content/datasets/images/CAKE/CAKE0070.png',
#  '/content/datasets/images/CAKE/CAKE0071.png',
#  '/content/datasets/images/CAKE/CAKE0072.png',
#  '/content/datasets/images/CAKE/CAKE0073.png',
#  '/content/datasets/images/CAKE/CAKE0074.png',
#  '/content/datasets/images/CAKE/CAKE0075.png',
#  '/content/datasets/images/CAKE/CAKE0076.png',
#  '/content/datasets/images/CAKE/CAKE0077.png',
#  '/content/datasets/images/CAKE/CAKE0078.png',
#  '/content/datasets/images/CAKE/CAKE0079.png',
#  '/content/datasets/images/CAKE/CAKE0080.png',
#  '/content/datasets/images/CAKE/CAKE0081.png',
#  '/content/datasets/images/CAKE/CAKE0082.png',
#  '/content/datasets/images/CAKE/CAKE0083.png',
#  '/content/datasets/images/CAKE/CAKE0084.png',
#  '/content/datasets/images/CAKE/CAKE0085.png',
#  '/content/datasets/images/CAKE/CAKE0086.png',
#  '/content/datasets/images/CAKE/CAKE0087.png',
#  '/content/datasets/images/CAKE/CAKE0088.png',
#  '/content/datasets/images/CAKE/CAKE0089.png',
#  '/content/datasets/images/CAKE/CAKE0090.png',
#  '/content/datasets/images/CAKE/CAKE0091.png',
#  '/content/datasets/images/CAKE/CAKE0092.png',
#  '/content/datasets/images/CAKE/CAKE0093.png',
#  '/content/datasets/images/CAKE/CAKE0094.png',
#  '/content/datasets/images/CAKE/CAKE0095.png',
#  '/content/datasets/images/CAKE/CAKE0096.png',
#  '/content/datasets/images/CAKE/CAKE0097.png',
#  '/content/datasets/images/CAKE/CAKE0098.png',
#  '/content/datasets/images/CAKE/CAKE0099.png',
#  '/content/datasets/images/CAKE/CAKE0100.png',
#  '/content/datasets/images/CAKE/CAKE0101.png',
#  '/content/datasets/images/CAKE/CAKE0102.png',
#  '/content/datasets/images/CAKE/CAKE0103.png',
#  '/content/datasets/images/CAKE/CAKE0104.png',
#  '/content/datasets/images/CAKE/CAKE0105.png',
#  '/content/datasets/images/CAKE/CAKE0106.png',
#  '/content/datasets/images/CAKE/CAKE0107.png',
#  '/content/datasets/images/CAKE/CAKE0108.png',
#  '/content/datasets/images/CAKE/CAKE0109.png',
#  '/content/datasets/images/CAKE/CAKE0110.png',
#  '/content/datasets/images/CAKE/CAKE0111.png',
#  '/content/datasets/images/CAKE/CAKE0112.png',
#  '/content/datasets/images/CAKE/CAKE0113.png',
#  '/content/datasets/images/CAKE/CAKE0114.png',
#  '/content/datasets/images/CAKE/CAKE0115.png',
#  '/content/datasets/images/CAKE/CAKE0116.png',
#  '/content/datasets/images/CAKE/CAKE0117.png',
#  '/content/datasets/images/CAKE/CAKE0118.png',
#  '/content/datasets/images/CAKE/CAKE0119.png',
#  '/content/datasets/images/CAKE/CAKE0120.png',
#  '/content/datasets/images/CAKE/CAKE0121.png',
#  '/content/datasets/images/CAKE/CAKE0122.png',
#  '/content/datasets/images/CAKE/CAKE0123.png',
#  '/content/datasets/images/CAKE/CAKE0124.png',
#  '/content/datasets/images/CAKE/CAKE0125.png',
#  '/content/datasets/images/CAKE/CAKE0126.png',
#  '/content/datasets/images/CAKE/CAKE0127.png',
#  '/content/datasets/images/CAKE/CAKE0128.png',
#  '/content/datasets/images/CAKE/CAKE0129.png',
#  '/content/datasets/images/CAKE/CAKE0130.png',
#  '/content/datasets/images/CAKE/CAKE0131.png',
#  '/content/datasets/images/CAKE/CAKE0132.png',
#  '/content/datasets/images/CAKE/CAKE0133.png',
#  '/content/datasets/images/CAKE/CAKE0134.png',
#  '/content/datasets/images/CAKE/CAKE0135.png',
#  '/content/datasets/images/CAKE/CAKE0136.png',
#  '/content/datasets/images/CAKE/CAKE0137.png',
#  '/content/datasets/images/CAKE/CAKE0138.png',
#  '/content/datasets/images/CAKE/CAKE0139.png',
#  '/content/datasets/images/CAKE/CAKE0140.png',
#  '/content/datasets/images/CAKE/CAKE0141.png',
#  '/content/datasets/images/CAKE/CAKE0142.png',
#  '/content/datasets/images/CAKE/CAKE0143.png',
#  '/content/datasets/images/CAKE/CAKE0144.png',
#  '/content/datasets/images/CAKE/CAKE0145.png',
#  '/content/datasets/images/CAKE/CAKE0146.png',
#  '/content/datasets/images/CAKE/CAKE0147.png',
#  '/content/datasets/images/CAKE/CAKE0148.png',
#  '/content/datasets/images/CAKE/CAKE0149.png',
#  '/content/datasets/images/CAKE/CAKE0150.png',
#  '/content/datasets/images/CAKE/CAKE0151.png',
#  '/content/datasets/images/CAKE/CAKE0152.png',
#  '/content/datasets/images/CAKE/CAKE0153.png',
#  '/content/datasets/images/CAKE/CAKE0154.png',
#  '/content/datasets/images/CAKE/CAKE0155.png',
#  '/content/datasets/images/CAKE/CAKE0156.png',
#  '/content/datasets/images/CAKE/CAKE0157.png',
#  '/content/datasets/images/CAKE/CAKE0158.png',
#  '/content/datasets/images/CAKE/CAKE0159.png',
#  '/content/datasets/images/CAKE/CAKE0160.png',
#  '/content/datasets/images/CANDY/CANDY0000.png',
#  '/content/datasets/images/CANDY/CANDY0001.png',
#  '/content/datasets/images/CANDY/CANDY0002.png',
#  '/content/datasets/images/CANDY/CANDY0003.png',
#  '/content/datasets/images/CANDY/CANDY0004.png',
#  '/content/datasets/images/CANDY/CANDY0005.png',
#  '/content/datasets/images/CANDY/CANDY0006.png',
#  '/content/datasets/images/CANDY/CANDY0007.png',
#  '/content/datasets/images/CANDY/CANDY0008.png',
#  '/content/datasets/images/CANDY/CANDY0009.png',
#  '/content/datasets/images/CANDY/CANDY0010.png',
#  '/content/datasets/images/CANDY/CANDY0011.png',
#  '/content/datasets/images/CANDY/CANDY0012.png',
#  '/content/datasets/images/CANDY/CANDY0013.png',
#  '/content/datasets/images/CANDY/CANDY0014.png',
#  '/content/datasets/images/CANDY/CANDY0015.png',
#  '/content/datasets/images/CANDY/CANDY0016.png',
#  '/content/datasets/images/CANDY/CANDY0017.png',
#  '/content/datasets/images/CANDY/CANDY0018.png',
#  '/content/datasets/images/CANDY/CANDY0019.png',
#  '/content/datasets/images/CANDY/CANDY0020.png',
#  '/content/datasets/images/CANDY/CANDY0021.png',
#  '/content/datasets/images/CANDY/CANDY0022.png',
#  '/content/datasets/images/CANDY/CANDY0023.png',
#  '/content/datasets/images/CANDY/CANDY0024.png',
#  '/content/datasets/images/CANDY/CANDY0025.png',
#  '/content/datasets/images/CANDY/CANDY0026.png',
#  '/content/datasets/images/CANDY/CANDY0027.png',
#  '/content/datasets/images/CANDY/CANDY0028.png',
#  '/content/datasets/images/CANDY/CANDY0029.png',
#  '/content/datasets/images/CANDY/CANDY0030.png',
#  '/content/datasets/images/CANDY/CANDY0031.png',
#  '/content/datasets/images/CANDY/CANDY0032.png',
#  '/content/datasets/images/CANDY/CANDY0033.png',
#  '/content/datasets/images/CANDY/CANDY0034.png',
#  '/content/datasets/images/CANDY/CANDY0035.png',
#  '/content/datasets/images/CANDY/CANDY0036.png',
#  '/content/datasets/images/CANDY/CANDY0037.png',
#  '/content/datasets/images/CANDY/CANDY0038.png',
#  '/content/datasets/images/CANDY/CANDY0039.png',
#  '/content/datasets/images/CANDY/CANDY0040.png',
#  '/content/datasets/images/CANDY/CANDY0041.png',
#  '/content/datasets/images/CANDY/CANDY0042.png',
#  '/content/datasets/images/CANDY/CANDY0043.png',
#  '/content/datasets/images/CANDY/CANDY0044.png',
#  '/content/datasets/images/CANDY/CANDY0045.png',
#  '/content/datasets/images/CANDY/CANDY0046.png',
#  '/content/datasets/images/CANDY/CANDY0047.png',
#  '/content/datasets/images/CANDY/CANDY0048.png',
#  '/content/datasets/images/CANDY/CANDY0049.png',
#  '/content/datasets/images/CANDY/CANDY0050.png',
#  '/content/datasets/images/CANDY/CANDY0051.png',
#  '/content/datasets/images/CANDY/CANDY0052.png',
#  '/content/datasets/images/CANDY/CANDY0053.png',
#  '/content/datasets/images/CANDY/CANDY0054.png',
#  '/content/datasets/images/CANDY/CANDY0055.png',
#  '/content/datasets/images/CANDY/CANDY0056.png',
#  '/content/datasets/images/CANDY/CANDY0057.png',
#  '/content/datasets/images/CANDY/CANDY0058.png',
#  '/content/datasets/images/CANDY/CANDY0059.png',
#  '/content/datasets/images/CANDY/CANDY0060.png',
#  '/content/datasets/images/CANDY/CANDY0061.png',
#  '/content/datasets/images/CANDY/CANDY0062.png',
#  '/content/datasets/images/CANDY/CANDY0063.png',
#  '/content/datasets/images/CANDY/CANDY0064.png',
#  '/content/datasets/images/CANDY/CANDY0065.png',
#  '/content/datasets/images/CANDY/CANDY0066.png',
#  '/content/datasets/images/CANDY/CANDY0067.png',
#  '/content/datasets/images/CANDY/CANDY0068.png',
#  '/content/datasets/images/CANDY/CANDY0069.png',
#  '/content/datasets/images/CANDY/CANDY0070.png',
#  '/content/datasets/images/CANDY/CANDY0071.png',
#  '/content/datasets/images/CANDY/CANDY0072.png',
#  '/content/datasets/images/CANDY/CANDY0073.png',
#  '/content/datasets/images/CANDY/CANDY0074.png',
#  '/content/datasets/images/CANDY/CANDY0075.png',
#  '/content/datasets/images/CANDY/CANDY0076.png',
#  '/content/datasets/images/CANDY/CANDY0077.png',
#  '/content/datasets/images/CANDY/CANDY0078.png',
#  '/content/datasets/images/CANDY/CANDY0079.png',
#  '/content/datasets/images/CANDY/CANDY0080.png',
#  '/content/datasets/images/CANDY/CANDY0081.png',
#  '/content/datasets/images/CANDY/CANDY0082.png',
#  '/content/datasets/images/CANDY/CANDY0083.png',
#  '/content/datasets/images/CANDY/CANDY0084.png',
#  '/content/datasets/images/CANDY/CANDY0085.png',
#  '/content/datasets/images/CANDY/CANDY0086.png',
#  '/content/datasets/images/CANDY/CANDY0087.png',
#  '/content/datasets/images/CANDY/CANDY0088.png',
#  '/content/datasets/images/CANDY/CANDY0089.png',
#  '/content/datasets/images/CANDY/CANDY0090.png',
#  '/content/datasets/images/CANDY/CANDY0091.png',
#  '/content/datasets/images/CANDY/CANDY0092.png',
#  '/content/datasets/images/CANDY/CANDY0093.png',
#  '/content/datasets/images/CANDY/CANDY0094.png',
#  '/content/datasets/images/CANDY/CANDY0095.png',
#  '/content/datasets/images/CANDY/CANDY0096.png',
#  '/content/datasets/images/CANDY/CANDY0097.png',
#  '/content/datasets/images/CANDY/CANDY0098.png',
#  '/content/datasets/images/CANDY/CANDY0099.png',
#  '/content/datasets/images/CANDY/CANDY0100.png',
#  '/content/datasets/images/CANDY/CANDY0101.png',
#  '/content/datasets/images/CANDY/CANDY0102.png',
#  '/content/datasets/images/CANDY/CANDY0103.png',
#  '/content/datasets/images/CANDY/CANDY0104.png',
#  '/content/datasets/images/CANDY/CANDY0105.png',
#  '/content/datasets/images/CANDY/CANDY0106.png',
#  '/content/datasets/images/CANDY/CANDY0107.png',
#  '/content/datasets/images/CANDY/CANDY0108.png',
#  '/content/datasets/images/CANDY/CANDY0109.png',
#  '/content/datasets/images/CANDY/CANDY0110.png',
#  '/content/datasets/images/CANDY/CANDY0111.png',
#  '/content/datasets/images/CANDY/CANDY0112.png',
#  '/content/datasets/images/CANDY/CANDY0113.png',
#  '/content/datasets/images/CANDY/CANDY0114.png',
#  '/content/datasets/images/CANDY/CANDY0115.png',
#  '/content/datasets/images/CANDY/CANDY0116.png',
#  '/content/datasets/images/CANDY/CANDY0117.png',
#  '/content/datasets/images/CANDY/CANDY0118.png',
#  '/content/datasets/images/CANDY/CANDY0119.png',
#  '/content/datasets/images/CANDY/CANDY0120.png',
#  '/content/datasets/images/CANDY/CANDY0121.png',
#  '/content/datasets/images/CANDY/CANDY0122.png',
#  '/content/datasets/images/CANDY/CANDY0123.png',
#  '/content/datasets/images/CANDY/CANDY0124.png',
#  '/content/datasets/images/CANDY/CANDY0125.png',
#  '/content/datasets/images/CANDY/CANDY0126.png',
#  '/content/datasets/images/CANDY/CANDY0127.png',
#  '/content/datasets/images/CANDY/CANDY0128.png',
#  '/content/datasets/images/CANDY/CANDY0129.png',
#  '/content/datasets/images/CANDY/CANDY0130.png',
#  '/content/datasets/images/CANDY/CANDY0131.png',
#  '/content/datasets/images/CANDY/CANDY0132.png',
#  '/content/datasets/images/CANDY/CANDY0133.png',
#  '/content/datasets/images/CANDY/CANDY0134.png',
#  '/content/datasets/images/CANDY/CANDY0135.png',
#  '/content/datasets/images/CANDY/CANDY0136.png',
#  '/content/datasets/images/CANDY/CANDY0137.png',
#  '/content/datasets/images/CANDY/CANDY0138.png',
#  '/content/datasets/images/CANDY/CANDY0139.png',
#  '/content/datasets/images/CANDY/CANDY0140.png',
#  '/content/datasets/images/CANDY/CANDY0141.png',
#  '/content/datasets/images/CANDY/CANDY0142.png',
#  '/content/datasets/images/CANDY/CANDY0143.png',
#  '/content/datasets/images/CANDY/CANDY0144.png',
#  '/content/datasets/images/CANDY/CANDY0145.png',
#  '/content/datasets/images/CANDY/CANDY0146.png',
#  '/content/datasets/images/CANDY/CANDY0147.png',
#  '/content/datasets/images/CANDY/CANDY0148.png',
#  '/content/datasets/images/CANDY/CANDY0149.png',
#  '/content/datasets/images/CANDY/CANDY0150.png',
#  '/content/datasets/images/CANDY/CANDY0151.png',
#  '/content/datasets/images/CANDY/CANDY0152.png',
#  '/content/datasets/images/CANDY/CANDY0153.png',
#  '/content/datasets/images/CANDY/CANDY0154.png',
#  '/content/datasets/images/CANDY/CANDY0155.png',
#  '/content/datasets/images/CANDY/CANDY0156.png',
#  '/content/datasets/images/CANDY/CANDY0157.png',
#  '/content/datasets/images/CANDY/CANDY0158.png',
#  '/content/datasets/images/CANDY/CANDY0159.png',
#  '/content/datasets/images/CANDY/CANDY0160.png',
#  '/content/datasets/images/CANDY/CANDY0161.png',
#  '/content/datasets/images/CANDY/CANDY0162.png',
#  '/content/datasets/images/CANDY/CANDY0163.png',
#  '/content/datasets/images/CANDY/CANDY0164.png',
#  '/content/datasets/images/CANDY/CANDY0165.png',
#  '/content/datasets/images/CANDY/CANDY0166.png',
#  '/content/datasets/images/CANDY/CANDY0167.png',
#  '/content/datasets/images/CANDY/CANDY0168.png',
#  '/content/datasets/images/CANDY/CANDY0169.png',
#  '/content/datasets/images/CANDY/CANDY0170.png',
#  '/content/datasets/images/CANDY/CANDY0171.png',
#  '/content/datasets/images/CANDY/CANDY0172.png',
#  '/content/datasets/images/CANDY/CANDY0173.png',
#  '/content/datasets/images/CANDY/CANDY0174.png',
#  '/content/datasets/images/CANDY/CANDY0175.png',
#  '/content/datasets/images/CANDY/CANDY0176.png',
#  '/content/datasets/images/CANDY/CANDY0177.png',
#  '/content/datasets/images/CANDY/CANDY0178.png',
#  '/content/datasets/images/CANDY/CANDY0179.png',
#  '/content/datasets/images/CANDY/CANDY0180.png',
#  '/content/datasets/images/CANDY/CANDY0181.png',
#  '/content/datasets/images/CANDY/CANDY0182.png',
#  '/content/datasets/images/CANDY/CANDY0183.png',
#  '/content/datasets/images/CANDY/CANDY0184.png',
#  '/content/datasets/images/CANDY/CANDY0185.png',
#  '/content/datasets/images/CANDY/CANDY0186.png',
#  '/content/datasets/images/CANDY/CANDY0187.png',
#  '/content/datasets/images/CANDY/CANDY0188.png',
#  '/content/datasets/images/CANDY/CANDY0189.png',
#  '/content/datasets/images/CANDY/CANDY0190.png',
#  '/content/datasets/images/CANDY/CANDY0191.png',
#  '/content/datasets/images/CANDY/CANDY0192.png',
#  '/content/datasets/images/CANDY/CANDY0193.png',
#  '/content/datasets/images/CANDY/CANDY0194.png',
#  '/content/datasets/images/CANDY/CANDY0195.png',
#  '/content/datasets/images/CANDY/CANDY0196.png',
#  '/content/datasets/images/CANDY/CANDY0197.png',
#  '/content/datasets/images/CANDY/CANDY0198.png',
#  '/content/datasets/images/CANDY/CANDY0199.png',
#  '/content/datasets/images/CANDY/CANDY0200.png',
#  '/content/datasets/images/CANDY/CANDY0201.png',
#  '/content/datasets/images/CANDY/CANDY0202.png',
#  '/content/datasets/images/CANDY/CANDY0203.png',
#  '/content/datasets/images/CANDY/CANDY0204.png',
#  '/content/datasets/images/CANDY/CANDY0205.png',
#  '/content/datasets/images/CANDY/CANDY0206.png',
#  '/content/datasets/images/CANDY/CANDY0207.png',
#  '/content/datasets/images/CANDY/CANDY0208.png',
#  '/content/datasets/images/CANDY/CANDY0209.png',
#  '/content/datasets/images/CANDY/CANDY0210.png',
#  '/content/datasets/images/CANDY/CANDY0211.png',
#  '/content/datasets/images/CANDY/CANDY0212.png',
#  '/content/datasets/images/CANDY/CANDY0213.png',
#  '/content/datasets/images/CANDY/CANDY0214.png',
#  '/content/datasets/images/CANDY/CANDY0215.png',
#  '/content/datasets/images/CANDY/CANDY0216.png',
#  '/content/datasets/images/CANDY/CANDY0217.png',
#  '/content/datasets/images/CANDY/CANDY0218.png',
#  '/content/datasets/images/CANDY/CANDY0219.png',
#  '/content/datasets/images/CANDY/CANDY0220.png',
#  '/content/datasets/images/CANDY/CANDY0221.png',
#  '/content/datasets/images/CANDY/CANDY0222.png',
#  '/content/datasets/images/CANDY/CANDY0223.png',
#  '/content/datasets/images/CANDY/CANDY0224.png',
#  '/content/datasets/images/CANDY/CANDY0225.png',
#  '/content/datasets/images/CANDY/CANDY0226.png',
#  '/content/datasets/images/CANDY/CANDY0227.png',
#  '/content/datasets/images/CANDY/CANDY0228.png',
#  '/content/datasets/images/CANDY/CANDY0229.png',
#  '/content/datasets/images/CANDY/CANDY0230.png',
#  '/content/datasets/images/CANDY/CANDY0231.png',
#  '/content/datasets/images/CANDY/CANDY0232.png',
#  '/content/datasets/images/CANDY/CANDY0233.png',
#  '/content/datasets/images/CANDY/CANDY0234.png',
#  '/content/datasets/images/CANDY/CANDY0235.png',
#  '/content/datasets/images/CANDY/CANDY0236.png',
#  '/content/datasets/images/CANDY/CANDY0237.png',
#  '/content/datasets/images/CANDY/CANDY0238.png',
#  '/content/datasets/images/CANDY/CANDY0239.png',
#  '/content/datasets/images/CANDY/CANDY0240.png',
#  '/content/datasets/images/CANDY/CANDY0241.png',
#  '/content/datasets/images/CANDY/CANDY0242.png',
#  '/content/datasets/images/CANDY/CANDY0243.png',
#  '/content/datasets/images/CANDY/CANDY0244.png',
#  '/content/datasets/images/CANDY/CANDY0245.png',
#  '/content/datasets/images/CANDY/CANDY0246.png',
#  '/content/datasets/images/CANDY/CANDY0247.png',
#  '/content/datasets/images/CANDY/CANDY0248.png',
#  '/content/datasets/images/CANDY/CANDY0249.png',
#  '/content/datasets/images/CANDY/CANDY0250.png',
#  '/content/datasets/images/CANDY/CANDY0251.png',
#  '/content/datasets/images/CANDY/CANDY0252.png',
#  '/content/datasets/images/CANDY/CANDY0253.png',
#  '/content/datasets/images/CANDY/CANDY0254.png',
#  '/content/datasets/images/CANDY/CANDY0255.png',
#  '/content/datasets/images/CANDY/CANDY0256.png',
#  '/content/datasets/images/CANDY/CANDY0257.png',
#  '/content/datasets/images/CANDY/CANDY0258.png',
#  '/content/datasets/images/CANDY/CANDY0259.png',
#  '/content/datasets/images/CANDY/CANDY0260.png',
#  '/content/datasets/images/CANDY/CANDY0261.png',
#  '/content/datasets/images/CANDY/CANDY0262.png',
#  '/content/datasets/images/CANDY/CANDY0263.png',
#  '/content/datasets/images/CANDY/CANDY0264.png',
#  '/content/datasets/images/CANDY/CANDY0265.png',
#  '/content/datasets/images/CANDY/CANDY0266.png',
#  '/content/datasets/images/CANDY/CANDY0267.png',
#  '/content/datasets/images/CANDY/CANDY0268.png',
#  '/content/datasets/images/CANDY/CANDY0269.png',
#  '/content/datasets/images/CANDY/CANDY0270.png',
#  '/content/datasets/images/CANDY/CANDY0271.png',
#  '/content/datasets/images/CANDY/CANDY0272.png',
#  '/content/datasets/images/CANDY/CANDY0273.png',
#  '/content/datasets/images/CANDY/CANDY0274.png',
#  '/content/datasets/images/CANDY/CANDY0275.png',
#  '/content/datasets/images/CANDY/CANDY0276.png',
#  '/content/datasets/images/CANDY/CANDY0277.png',
#  '/content/datasets/images/CANDY/CANDY0278.png',
#  '/content/datasets/images/CANDY/CANDY0279.png',
#  '/content/datasets/images/CANDY/CANDY0280.png',
#  '/content/datasets/images/CANDY/CANDY0281.png',
#  '/content/datasets/images/CANDY/CANDY0282.png',
#  '/content/datasets/images/CANDY/CANDY0283.png',
#  '/content/datasets/images/CANDY/CANDY0284.png',
#  '/content/datasets/images/CANDY/CANDY0285.png',
#  '/content/datasets/images/CANDY/CANDY0286.png',
#  '/content/datasets/images/CANDY/CANDY0287.png',
#  '/content/datasets/images/CANDY/CANDY0288.png',
#  '/content/datasets/images/CANDY/CANDY0289.png',
#  '/content/datasets/images/CANDY/CANDY0290.png',
#  '/content/datasets/images/CANDY/CANDY0291.png',
#  '/content/datasets/images/CANDY/CANDY0292.png',
#  '/content/datasets/images/CANDY/CANDY0293.png',
#  '/content/datasets/images/CANDY/CANDY0294.png',
#  '/content/datasets/images/CANDY/CANDY0295.png',
#  '/content/datasets/images/CANDY/CANDY0296.png',
#  '/content/datasets/images/CANDY/CANDY0297.png',
#  '/content/datasets/images/CANDY/CANDY0298.png',
#  '/content/datasets/images/CANDY/CANDY0299.png',
#  '/content/datasets/images/CANDY/CANDY0300.png',
#  '/content/datasets/images/CANDY/CANDY0301.png',
#  '/content/datasets/images/CANDY/CANDY0302.png',
#  '/content/datasets/images/CANDY/CANDY0303.png',
#  '/content/datasets/images/CANDY/CANDY0304.png',
#  '/content/datasets/images/CANDY/CANDY0305.png',
#  '/content/datasets/images/CANDY/CANDY0306.png',
#  '/content/datasets/images/CANDY/CANDY0307.png',
#  '/content/datasets/images/CANDY/CANDY0308.png',
#  '/content/datasets/images/CANDY/CANDY0309.png',
#  '/content/datasets/images/CANDY/CANDY0310.png',
#  '/content/datasets/images/CANDY/CANDY0311.png',
#  '/content/datasets/images/CANDY/CANDY0312.png',
#  '/content/datasets/images/CANDY/CANDY0313.png',
#  '/content/datasets/images/CANDY/CANDY0314.png',
#  '/content/datasets/images/CANDY/CANDY0315.png',
#  '/content/datasets/images/CANDY/CANDY0316.png',
#  '/content/datasets/images/CANDY/CANDY0317.png',
#  '/content/datasets/images/CANDY/CANDY0318.png',
#  '/content/datasets/images/CANDY/CANDY0319.png',
#  '/content/datasets/images/CANDY/CANDY0320.png',
#  '/content/datasets/images/CANDY/CANDY0321.png',
#  '/content/datasets/images/CANDY/CANDY0322.png',
#  '/content/datasets/images/CANDY/CANDY0323.png',
#  '/content/datasets/images/CANDY/CANDY0324.png',
#  '/content/datasets/images/CANDY/CANDY0325.png',
#  '/content/datasets/images/CANDY/CANDY0326.png',
#  '/content/datasets/images/CANDY/CANDY0327.png',
#  '/content/datasets/images/CANDY/CANDY0328.png',
#  '/content/datasets/images/CANDY/CANDY0329.png',
#  '/content/datasets/images/CANDY/CANDY0330.png',
#  '/content/datasets/images/CANDY/CANDY0331.png',
#  '/content/datasets/images/CANDY/CANDY0332.png',
#  '/content/datasets/images/CANDY/CANDY0333.png',
#  '/content/datasets/images/CANDY/CANDY0334.png',
#  '/content/datasets/images/CANDY/CANDY0335.png',
#  '/content/datasets/images/CANDY/CANDY0336.png',
#  '/content/datasets/images/CANDY/CANDY0337.png',
#  '/content/datasets/images/CANDY/CANDY0338.png',
#  '/content/datasets/images/CANDY/CANDY0339.png',
#  '/content/datasets/images/CANDY/CANDY0340.png',
#  '/content/datasets/images/CANDY/CANDY0341.png',
#  '/content/datasets/images/CANDY/CANDY0342.png',
#  '/content/datasets/images/CANDY/CANDY0343.png',
#  '/content/datasets/images/CANDY/CANDY0344.png',
#  '/content/datasets/images/CANDY/CANDY0345.png',
#  '/content/datasets/images/CANDY/CANDY0346.png',
#  '/content/datasets/images/CANDY/CANDY0347.png',
#  '/content/datasets/images/CANDY/CANDY0348.png',
#  '/content/datasets/images/CANDY/CANDY0349.png',
#  '/content/datasets/images/CANDY/CANDY0350.png',
#  '/content/datasets/images/CANDY/CANDY0351.png',
#  '/content/datasets/images/CANDY/CANDY0352.png',
#  '/content/datasets/images/CANDY/CANDY0353.png',
#  '/content/datasets/images/CANDY/CANDY0354.png',
#  '/content/datasets/images/CANDY/CANDY0355.png',
#  '/content/datasets/images/CANDY/CANDY0356.png',
#  '/content/datasets/images/CANDY/CANDY0357.png',
#  '/content/datasets/images/CANDY/CANDY0358.png',
#  '/content/datasets/images/CANDY/CANDY0359.png',
#  '/content/datasets/images/CANDY/CANDY0360.png',
#  '/content/datasets/images/CANDY/CANDY0361.png',
#  '/content/datasets/images/CANDY/CANDY0362.png',
#  '/content/datasets/images/CANDY/CANDY0363.png',
#  '/content/datasets/images/CANDY/CANDY0364.png',
#  '/content/datasets/images/CANDY/CANDY0365.png',
#  '/content/datasets/images/CANDY/CANDY0366.png',
#  '/content/datasets/images/CANDY/CANDY0367.png',
#  '/content/datasets/images/CANDY/CANDY0368.png',
#  '/content/datasets/images/CANDY/CANDY0369.png',
#  '/content/datasets/images/CANDY/CANDY0370.png',
#  '/content/datasets/images/CANDY/CANDY0371.png',
#  '/content/datasets/images/CEREAL/CEREAL0000.png',
#  '/content/datasets/images/CEREAL/CEREAL0001.png',
#  '/content/datasets/images/CEREAL/CEREAL0002.png',
#  '/content/datasets/images/CEREAL/CEREAL0003.png',
#  '/content/datasets/images/CEREAL/CEREAL0004.png',
#  '/content/datasets/images/CEREAL/CEREAL0005.png',
#  '/content/datasets/images/CEREAL/CEREAL0006.png',
#  '/content/datasets/images/CEREAL/CEREAL0007.png',
#  '/content/datasets/images/CEREAL/CEREAL0008.png',
#  '/content/datasets/images/CEREAL/CEREAL0009.png',
#  '/content/datasets/images/CEREAL/CEREAL0010.png',
#  '/content/datasets/images/CEREAL/CEREAL0011.png',
#  '/content/datasets/images/CEREAL/CEREAL0012.png',
#  '/content/datasets/images/CEREAL/CEREAL0013.png',
#  '/content/datasets/images/CEREAL/CEREAL0014.png',
#  '/content/datasets/images/CEREAL/CEREAL0015.png',
#  '/content/datasets/images/CEREAL/CEREAL0016.png',
#  '/content/datasets/images/CEREAL/CEREAL0017.png',
#  '/content/datasets/images/CEREAL/CEREAL0018.png',
#  '/content/datasets/images/CEREAL/CEREAL0019.png',
#  '/content/datasets/images/CEREAL/CEREAL0020.png',
#  '/content/datasets/images/CEREAL/CEREAL0021.png',
#  '/content/datasets/images/CEREAL/CEREAL0022.png',
#  '/content/datasets/images/CEREAL/CEREAL0023.png',
#  '/content/datasets/images/CEREAL/CEREAL0024.png',
#  '/content/datasets/images/CEREAL/CEREAL0025.png',
#  '/content/datasets/images/CEREAL/CEREAL0026.png',
#  '/content/datasets/images/CEREAL/CEREAL0027.png',
#  '/content/datasets/images/CEREAL/CEREAL0028.png',
#  '/content/datasets/images/CEREAL/CEREAL0029.png',
#  '/content/datasets/images/CEREAL/CEREAL0030.png',
#  '/content/datasets/images/CEREAL/CEREAL0031.png',
#  '/content/datasets/images/CEREAL/CEREAL0032.png',
#  '/content/datasets/images/CEREAL/CEREAL0033.png',
#  '/content/datasets/images/CEREAL/CEREAL0034.png',
#  '/content/datasets/images/CEREAL/CEREAL0035.png',
#  '/content/datasets/images/CEREAL/CEREAL0036.png',
#  '/content/datasets/images/CEREAL/CEREAL0037.png',
#  '/content/datasets/images/CEREAL/CEREAL0038.png',
#  '/content/datasets/images/CEREAL/CEREAL0039.png',
#  '/content/datasets/images/CEREAL/CEREAL0040.png',
#  '/content/datasets/images/CEREAL/CEREAL0041.png',
#  '/content/datasets/images/CEREAL/CEREAL0042.png',
#  '/content/datasets/images/CEREAL/CEREAL0043.png',
#  '/content/datasets/images/CEREAL/CEREAL0044.png',
#  '/content/datasets/images/CEREAL/CEREAL0045.png',
#  '/content/datasets/images/CEREAL/CEREAL0046.png',
#  '/content/datasets/images/CEREAL/CEREAL0047.png',
#  '/content/datasets/images/CEREAL/CEREAL0048.png',
#  '/content/datasets/images/CEREAL/CEREAL0049.png',
#  '/content/datasets/images/CEREAL/CEREAL0050.png',
#  '/content/datasets/images/CEREAL/CEREAL0051.png',
#  '/content/datasets/images/CEREAL/CEREAL0052.png',
#  '/content/datasets/images/CEREAL/CEREAL0053.png',
#  '/content/datasets/images/CEREAL/CEREAL0054.png',
#  '/content/datasets/images/CEREAL/CEREAL0055.png',
#  '/content/datasets/images/CEREAL/CEREAL0056.png',
#  '/content/datasets/images/CEREAL/CEREAL0057.png',
#  '/content/datasets/images/CEREAL/CEREAL0058.png',
#  '/content/datasets/images/CEREAL/CEREAL0059.png',
#  '/content/datasets/images/CEREAL/CEREAL0060.png',
#  '/content/datasets/images/CEREAL/CEREAL0061.png',
#  '/content/datasets/images/CEREAL/CEREAL0062.png',
#  '/content/datasets/images/CEREAL/CEREAL0063.png',
#  '/content/datasets/images/CEREAL/CEREAL0064.png',
#  '/content/datasets/images/CEREAL/CEREAL0065.png',
#  '/content/datasets/images/CEREAL/CEREAL0066.png',
#  '/content/datasets/images/CEREAL/CEREAL0067.png',
#  '/content/datasets/images/CEREAL/CEREAL0068.png',
#  '/content/datasets/images/CEREAL/CEREAL0069.png',
#  '/content/datasets/images/CEREAL/CEREAL0070.png',
#  '/content/datasets/images/CEREAL/CEREAL0071.png',
#  '/content/datasets/images/CEREAL/CEREAL0072.png',
#  '/content/datasets/images/CEREAL/CEREAL0073.png',
#  '/content/datasets/images/CEREAL/CEREAL0074.png',
#  '/content/datasets/images/CEREAL/CEREAL0075.png',
#  '/content/datasets/images/CEREAL/CEREAL0076.png',
#  '/content/datasets/images/CEREAL/CEREAL0077.png',
#  '/content/datasets/images/CEREAL/CEREAL0078.png',
#  '/content/datasets/images/CEREAL/CEREAL0079.png',
#  '/content/datasets/images/CEREAL/CEREAL0080.png',
#  '/content/datasets/images/CEREAL/CEREAL0081.png',
#  '/content/datasets/images/CEREAL/CEREAL0082.png',
#  '/content/datasets/images/CEREAL/CEREAL0083.png',
#  '/content/datasets/images/CEREAL/CEREAL0084.png',
#  '/content/datasets/images/CEREAL/CEREAL0085.png',
#  '/content/datasets/images/CEREAL/CEREAL0086.png',
#  '/content/datasets/images/CEREAL/CEREAL0087.png',
#  '/content/datasets/images/CEREAL/CEREAL0088.png',
#  '/content/datasets/images/CEREAL/CEREAL0089.png',
#  '/content/datasets/images/CEREAL/CEREAL0090.png',
#  '/content/datasets/images/CEREAL/CEREAL0091.png',
#  '/content/datasets/images/CEREAL/CEREAL0092.png',
#  '/content/datasets/images/CEREAL/CEREAL0093.png',
#  '/content/datasets/images/CEREAL/CEREAL0094.png',
#  '/content/datasets/images/CEREAL/CEREAL0095.png',
#  '/content/datasets/images/CEREAL/CEREAL0096.png',
#  '/content/datasets/images/CEREAL/CEREAL0097.png',
#  '/content/datasets/images/CEREAL/CEREAL0098.png',
#  '/content/datasets/images/CEREAL/CEREAL0099.png',
#  '/content/datasets/images/CEREAL/CEREAL0100.png',
#  '/content/datasets/images/CEREAL/CEREAL0101.png',
#  '/content/datasets/images/CEREAL/CEREAL0102.png',
#  '/content/datasets/images/CEREAL/CEREAL0103.png',
#  '/content/datasets/images/CEREAL/CEREAL0104.png',
#  '/content/datasets/images/CEREAL/CEREAL0105.png',
#  '/content/datasets/images/CEREAL/CEREAL0106.png',
#  '/content/datasets/images/CEREAL/CEREAL0107.png',
#  '/content/datasets/images/CEREAL/CEREAL0108.png',
#  '/content/datasets/images/CEREAL/CEREAL0109.png',
#  '/content/datasets/images/CEREAL/CEREAL0110.png',
#  '/content/datasets/images/CEREAL/CEREAL0111.png',
#  '/content/datasets/images/CEREAL/CEREAL0112.png',
#  '/content/datasets/images/CEREAL/CEREAL0113.png',
#  '/content/datasets/images/CEREAL/CEREAL0114.png',
#  '/content/datasets/images/CEREAL/CEREAL0115.png',
#  '/content/datasets/images/CEREAL/CEREAL0116.png',
#  '/content/datasets/images/CEREAL/CEREAL0117.png',
#  '/content/datasets/images/CEREAL/CEREAL0118.png',
#  '/content/datasets/images/CEREAL/CEREAL0119.png',
#  '/content/datasets/images/CEREAL/CEREAL0120.png',
#  '/content/datasets/images/CEREAL/CEREAL0121.png',
#  '/content/datasets/images/CEREAL/CEREAL0122.png',
#  '/content/datasets/images/CEREAL/CEREAL0123.png',
#  '/content/datasets/images/CEREAL/CEREAL0124.png',
#  '/content/datasets/images/CEREAL/CEREAL0125.png',
#  '/content/datasets/images/CEREAL/CEREAL0126.png',
#  '/content/datasets/images/CEREAL/CEREAL0127.png',
#  '/content/datasets/images/CEREAL/CEREAL0128.png',
#  '/content/datasets/images/CEREAL/CEREAL0129.png',
#  '/content/datasets/images/CEREAL/CEREAL0130.png',
#  '/content/datasets/images/CEREAL/CEREAL0131.png',
#  '/content/datasets/images/CEREAL/CEREAL0132.png',
#  '/content/datasets/images/CEREAL/CEREAL0133.png',
#  '/content/datasets/images/CEREAL/CEREAL0134.png',
#  '/content/datasets/images/CEREAL/CEREAL0135.png',
#  '/content/datasets/images/CEREAL/CEREAL0136.png',
#  '/content/datasets/images/CEREAL/CEREAL0137.png',
#  '/content/datasets/images/CEREAL/CEREAL0138.png',
#  '/content/datasets/images/CEREAL/CEREAL0139.png',
#  '/content/datasets/images/CEREAL/CEREAL0140.png',
#  '/content/datasets/images/CEREAL/CEREAL0141.png',
#  '/content/datasets/images/CEREAL/CEREAL0142.png',
#  '/content/datasets/images/CEREAL/CEREAL0143.png',
#  '/content/datasets/images/CEREAL/CEREAL0144.png',
#  '/content/datasets/images/CEREAL/CEREAL0145.png',
#  '/content/datasets/images/CEREAL/CEREAL0146.png',
#  '/content/datasets/images/CEREAL/CEREAL0147.png',
#  '/content/datasets/images/CEREAL/CEREAL0148.png',
#  '/content/datasets/images/CEREAL/CEREAL0149.png',
#  '/content/datasets/images/CEREAL/CEREAL0150.png',
#  '/content/datasets/images/CEREAL/CEREAL0151.png',
#  '/content/datasets/images/CEREAL/CEREAL0152.png',
#  '/content/datasets/images/CEREAL/CEREAL0153.png',
#  '/content/datasets/images/CEREAL/CEREAL0154.png',
#  '/content/datasets/images/CEREAL/CEREAL0155.png',
#  '/content/datasets/images/CEREAL/CEREAL0156.png',
#  '/content/datasets/images/CEREAL/CEREAL0157.png',
#  '/content/datasets/images/CEREAL/CEREAL0158.png',
#  '/content/datasets/images/CEREAL/CEREAL0159.png',
#  '/content/datasets/images/CEREAL/CEREAL0160.png',
#  '/content/datasets/images/CEREAL/CEREAL0161.png',
#  '/content/datasets/images/CEREAL/CEREAL0162.png',
#  '/content/datasets/images/CEREAL/CEREAL0163.png',
#  '/content/datasets/images/CEREAL/CEREAL0164.png',
#  '/content/datasets/images/CEREAL/CEREAL0165.png',
#  '/content/datasets/images/CEREAL/CEREAL0166.png',
#  '/content/datasets/images/CEREAL/CEREAL0167.png',
#  '/content/datasets/images/CEREAL/CEREAL0168.png',
#  '/content/datasets/images/CEREAL/CEREAL0169.png',
#  '/content/datasets/images/CEREAL/CEREAL0170.png',
#  '/content/datasets/images/CEREAL/CEREAL0171.png',
#  '/content/datasets/images/CEREAL/CEREAL0172.png',
#  '/content/datasets/images/CEREAL/CEREAL0173.png',
#  '/content/datasets/images/CEREAL/CEREAL0174.png',
#  '/content/datasets/images/CEREAL/CEREAL0175.png',
#  '/content/datasets/images/CEREAL/CEREAL0176.png',
#  '/content/datasets/images/CEREAL/CEREAL0177.png',
#  '/content/datasets/images/CEREAL/CEREAL0178.png',
#  '/content/datasets/images/CEREAL/CEREAL0179.png',
#  '/content/datasets/images/CEREAL/CEREAL0180.png',
#  '/content/datasets/images/CEREAL/CEREAL0181.png',
#  '/content/datasets/images/CEREAL/CEREAL0182.png',
#  '/content/datasets/images/CEREAL/CEREAL0183.png',
#  '/content/datasets/images/CEREAL/CEREAL0184.png',
#  '/content/datasets/images/CEREAL/CEREAL0185.png',
#  '/content/datasets/images/CEREAL/CEREAL0186.png',
#  '/content/datasets/images/CEREAL/CEREAL0187.png',
#  '/content/datasets/images/CEREAL/CEREAL0188.png',
#  '/content/datasets/images/CEREAL/CEREAL0189.png',
#  '/content/datasets/images/CEREAL/CEREAL0190.png',
#  '/content/datasets/images/CEREAL/CEREAL0191.png',
#  '/content/datasets/images/CEREAL/CEREAL0192.png',
#  '/content/datasets/images/CEREAL/CEREAL0193.png',
#  '/content/datasets/images/CEREAL/CEREAL0194.png',
#  '/content/datasets/images/CEREAL/CEREAL0195.png',
#  '/content/datasets/images/CEREAL/CEREAL0196.png',
#  '/content/datasets/images/CEREAL/CEREAL0197.png',
#  '/content/datasets/images/CEREAL/CEREAL0198.png',
#  '/content/datasets/images/CEREAL/CEREAL0199.png',
#  '/content/datasets/images/CEREAL/CEREAL0200.png',
#  '/content/datasets/images/CEREAL/CEREAL0201.png',
#  '/content/datasets/images/CEREAL/CEREAL0202.png',
#  '/content/datasets/images/CEREAL/CEREAL0203.png',
#  '/content/datasets/images/CEREAL/CEREAL0204.png',
#  '/content/datasets/images/CEREAL/CEREAL0205.png',
#  '/content/datasets/images/CEREAL/CEREAL0206.png',
#  '/content/datasets/images/CEREAL/CEREAL0207.png',
#  '/content/datasets/images/CEREAL/CEREAL0208.png',
#  '/content/datasets/images/CEREAL/CEREAL0209.png',
#  '/content/datasets/images/CEREAL/CEREAL0210.png',
#  '/content/datasets/images/CEREAL/CEREAL0211.png',
#  '/content/datasets/images/CEREAL/CEREAL0212.png',
#  '/content/datasets/images/CEREAL/CEREAL0213.png',
#  '/content/datasets/images/CEREAL/CEREAL0214.png',
#  '/content/datasets/images/CEREAL/CEREAL0215.png',
#  '/content/datasets/images/CEREAL/CEREAL0216.png',
#  '/content/datasets/images/CEREAL/CEREAL0217.png',
#  '/content/datasets/images/CEREAL/CEREAL0218.png',
#  '/content/datasets/images/CEREAL/CEREAL0219.png',
#  '/content/datasets/images/CEREAL/CEREAL0220.png',
#  '/content/datasets/images/CEREAL/CEREAL0221.png',
#  '/content/datasets/images/CEREAL/CEREAL0222.png',
#  '/content/datasets/images/CEREAL/CEREAL0223.png',
#  '/content/datasets/images/CEREAL/CEREAL0224.png',
#  '/content/datasets/images/CEREAL/CEREAL0225.png',
#  '/content/datasets/images/CEREAL/CEREAL0226.png',
#  '/content/datasets/images/CEREAL/CEREAL0227.png',
#  '/content/datasets/images/CEREAL/CEREAL0228.png',
#  '/content/datasets/images/CEREAL/CEREAL0229.png',
#  '/content/datasets/images/CEREAL/CEREAL0230.png',
#  '/content/datasets/images/CEREAL/CEREAL0231.png',
#  '/content/datasets/images/CEREAL/CEREAL0232.png',
#  '/content/datasets/images/CEREAL/CEREAL0233.png',
#  '/content/datasets/images/CEREAL/CEREAL0234.png',
#  '/content/datasets/images/CEREAL/CEREAL0235.png',
#  '/content/datasets/images/CEREAL/CEREAL0236.png',
#  '/content/datasets/images/CEREAL/CEREAL0237.png',
#  '/content/datasets/images/CEREAL/CEREAL0238.png',
#  '/content/datasets/images/CEREAL/CEREAL0239.png',
#  '/content/datasets/images/CEREAL/CEREAL0240.png',
#  '/content/datasets/images/CEREAL/CEREAL0241.png',
#  '/content/datasets/images/CEREAL/CEREAL0242.png',
#  '/content/datasets/images/CEREAL/CEREAL0243.png',
#  '/content/datasets/images/CEREAL/CEREAL0244.png',
#  '/content/datasets/images/CEREAL/CEREAL0245.png',
#  '/content/datasets/images/CEREAL/CEREAL0246.png',
#  '/content/datasets/images/CEREAL/CEREAL0247.png',
#  '/content/datasets/images/CEREAL/CEREAL0248.png',
#  '/content/datasets/images/CEREAL/CEREAL0249.png',
#  '/content/datasets/images/CEREAL/CEREAL0250.png',
#  '/content/datasets/images/CEREAL/CEREAL0251.png',
#  '/content/datasets/images/CEREAL/CEREAL0252.png',
#  '/content/datasets/images/CEREAL/CEREAL0253.png',
#  '/content/datasets/images/CEREAL/CEREAL0254.png',
#  '/content/datasets/images/CEREAL/CEREAL0255.png',
#  '/content/datasets/images/CEREAL/CEREAL0256.png',
#  '/content/datasets/images/CEREAL/CEREAL0257.png',
#  '/content/datasets/images/CEREAL/CEREAL0258.png',
#  '/content/datasets/images/CEREAL/CEREAL0259.png',
#  '/content/datasets/images/CEREAL/CEREAL0260.png',
#  '/content/datasets/images/CEREAL/CEREAL0261.png',
#  '/content/datasets/images/CEREAL/CEREAL0262.png',
#  '/content/datasets/images/CEREAL/CEREAL0263.png',
#  '/content/datasets/images/CEREAL/CEREAL0264.png',
#  '/content/datasets/images/CEREAL/CEREAL0265.png',
#  '/content/datasets/images/CEREAL/CEREAL0266.png',
#  '/content/datasets/images/CEREAL/CEREAL0267.png',
#  '/content/datasets/images/CEREAL/CEREAL0268.png',
#  '/content/datasets/images/CEREAL/CEREAL0269.png',
#  '/content/datasets/images/CEREAL/CEREAL0270.png',
#  '/content/datasets/images/CEREAL/CEREAL0271.png',
#  '/content/datasets/images/CEREAL/CEREAL0272.png',
#  '/content/datasets/images/CEREAL/CEREAL0273.png',
#  '/content/datasets/images/CEREAL/CEREAL0274.png',
#  '/content/datasets/images/CEREAL/CEREAL0275.png',
#  '/content/datasets/images/CEREAL/CEREAL0276.png',
#  '/content/datasets/images/CEREAL/CEREAL0277.png',
#  '/content/datasets/images/CHIPS/CHIPS0000.png',
#  '/content/datasets/images/CHIPS/CHIPS0001.png',
#  '/content/datasets/images/CHIPS/CHIPS0002.png',
#  '/content/datasets/images/CHIPS/CHIPS0003.png',
#  '/content/datasets/images/CHIPS/CHIPS0004.png',
#  '/content/datasets/images/CHIPS/CHIPS0005.png',
#  '/content/datasets/images/CHIPS/CHIPS0006.png',
#  '/content/datasets/images/CHIPS/CHIPS0007.png',
#  '/content/datasets/images/CHIPS/CHIPS0008.png',
#  '/content/datasets/images/CHIPS/CHIPS0009.png',
#  '/content/datasets/images/CHIPS/CHIPS0010.png',
#  '/content/datasets/images/CHIPS/CHIPS0011.png',
#  '/content/datasets/images/CHIPS/CHIPS0012.png',
#  '/content/datasets/images/CHIPS/CHIPS0013.png',
#  '/content/datasets/images/CHIPS/CHIPS0014.png',
#  '/content/datasets/images/CHIPS/CHIPS0015.png',
#  '/content/datasets/images/CHIPS/CHIPS0016.png',
#  '/content/datasets/images/CHIPS/CHIPS0017.png',
#  '/content/datasets/images/CHIPS/CHIPS0018.png',
#  '/content/datasets/images/CHIPS/CHIPS0019.png',
#  '/content/datasets/images/CHIPS/CHIPS0020.png',
#  '/content/datasets/images/CHIPS/CHIPS0021.png',
#  '/content/datasets/images/CHIPS/CHIPS0022.png',
#  '/content/datasets/images/CHIPS/CHIPS0023.png',
#  '/content/datasets/images/CHIPS/CHIPS0024.png',
#  '/content/datasets/images/CHIPS/CHIPS0025.png',
#  '/content/datasets/images/CHIPS/CHIPS0026.png',
#  '/content/datasets/images/CHIPS/CHIPS0027.png',
#  '/content/datasets/images/CHIPS/CHIPS0028.png',
#  '/content/datasets/images/CHIPS/CHIPS0029.png',
#  '/content/datasets/images/CHIPS/CHIPS0030.png',
#  '/content/datasets/images/CHIPS/CHIPS0031.png',
#  '/content/datasets/images/CHIPS/CHIPS0032.png',
#  '/content/datasets/images/CHIPS/CHIPS0033.png',
#  '/content/datasets/images/CHIPS/CHIPS0034.png',
#  '/content/datasets/images/CHIPS/CHIPS0035.png',
#  '/content/datasets/images/CHIPS/CHIPS0036.png',
#  '/content/datasets/images/CHIPS/CHIPS0037.png',
#  '/content/datasets/images/CHIPS/CHIPS0038.png',
#  '/content/datasets/images/CHIPS/CHIPS0039.png',
#  '/content/datasets/images/CHIPS/CHIPS0040.png',
#  '/content/datasets/images/CHIPS/CHIPS0041.png',
#  '/content/datasets/images/CHIPS/CHIPS0042.png',
#  '/content/datasets/images/CHIPS/CHIPS0043.png',
#  '/content/datasets/images/CHIPS/CHIPS0044.png',
#  '/content/datasets/images/CHIPS/CHIPS0045.png',
#  '/content/datasets/images/CHIPS/CHIPS0046.png',
#  '/content/datasets/images/CHIPS/CHIPS0047.png',
#  '/content/datasets/images/CHIPS/CHIPS0048.png',
#  '/content/datasets/images/CHIPS/CHIPS0049.png',
#  '/content/datasets/images/CHIPS/CHIPS0050.png',
#  '/content/datasets/images/CHIPS/CHIPS0051.png',
#  '/content/datasets/images/CHIPS/CHIPS0052.png',
#  ...]

# %%
IMG_SIZE = 128
IMG_HEIGHT=128
IMG_WIDTH = 128
img_data_array=[]
# x_data = np.empty((len(img_list), IMG_SIZE, IMG_SIZE, 3), dtype=np.float32)
for i, img_path in enumerate(img_list):

  image= cv2.imread( img_path)
  image=cv2.resize(image, (IMG_HEIGHT, IMG_WIDTH),interpolation = cv2.INTER_AREA)
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image=np.array(image)
  image = image.astype('float32')
  image /= 255 
  img_data_array.append(image)

# %%
img_data=np.array(img_data_array, np.float32)

# %%
len(img_list)
# Out:
# 4947

# %%
del img_data_array

# %%
train_images, test_images,_, _ = train_test_split(img_data, img_data, test_size=0.05, random_state=42)

# %%
train_images=train_images.reshape((train_images.shape[0],train_images.shape[1], train_images.shape[2], 3))
test_images=test_images.reshape((test_images.shape[0],test_images.shape[1], test_images.shape[2], 3))

# %%
print(train_images.shape)
print(test_images.shape)
# Out:
# (4699, 128, 128, 3)
# (248, 128, 128, 3)

# %%
del img_data

# %%
plt.imshow((tf.squeeze(train_images[3])),cmap="gray")

# %%
plt.imshow(train_images[0])

# %%
print(train_images.shape)
print(test_images.shape)
# Out:
# (4699, 128, 128, 3)
# (248, 128, 128, 3)

# %%
train_size =4699
batch_size = 32
test_size = 248

# %% [markdown]
# ## Use *tf.data* to batch and shuffle the data

# %%
train_dataset = (tf.data.Dataset.from_tensor_slices(train_images)
                 .shuffle(train_size).batch(batch_size))
test_dataset = (tf.data.Dataset.from_tensor_slices(test_images)
                .shuffle(test_size).batch(batch_size))

# %%
train_dataset
# Out:
# <BatchDataset shapes: (None, 128, 128, 3), types: tf.float32>

# %% [markdown]
# ## Define the encoder and decoder networks with *tf.keras.Sequential*
#
# In this VAE example, use two small ConvNets for the encoder and decoder networks. In the literature, these networks are also referred to as inference/recognition and generative models respectively. Use `tf.keras.Sequential` to simplify implementation. Let $x$ and $z$ denote the observation and latent variable respectively in the following descriptions.
#
# ### Encoder network
# This defines the approximate posterior distribution $q(z|x)$, which takes as input an observation and outputs a set of parameters for specifying the conditional distribution of the latent representation $z$.
# In this example, simply model the distribution as a diagonal Gaussian, and the network outputs the mean and log-variance parameters of a factorized Gaussian.
# Output log-variance instead of the variance directly for numerical stability.
#
# ### Decoder network
# This defines the conditional distribution of the observation $p(x|z)$, which takes a latent sample $z$ as input and outputs the parameters for a conditional distribution of the observation.
# Model the latent distribution prior $p(z)$ as a unit Gaussian.
#
# ### Reparameterization trick
# To generate a sample $z$ for the decoder during training, you can sample from the latent distribution defined by the parameters outputted by the encoder, given an input observation $x$.
# However, this sampling operation creates a bottleneck because backpropagation cannot flow through a random node.
#
# To address this, use a reparameterization trick.
# In our example, you approximate $z$ using the decoder parameters and another parameter $\epsilon$ as follows:
#
# $$z = \mu + \sigma \odot \epsilon$$
#
# where $\mu$ and $\sigma$ represent the mean and standard deviation of a Gaussian distribution respectively. They can be derived from the decoder output. The $\epsilon$ can be thought of as a random noise used to maintain stochasticity of $z$. Generate $\epsilon$ from a standard normal distribution.
#
# The latent variable $z$ is now generated by a function of $\mu$, $\sigma$ and $\epsilon$, which would enable the model to backpropagate gradients in the encoder through $\mu$ and $\sigma$ respectively, while maintaining stochasticity through $\epsilon$.
#
# ### Network architecture
# For the encoder network, use two convolutional layers followed by a fully-connected layer. In the decoder network, mirror this architecture by using a fully-connected layer followed by three convolution transpose layers (a.k.a. deconvolutional layers in some contexts). Note, it's common practice to avoid using batch normalization when training VAEs, since the additional stochasticity due to using mini-batches may aggravate instability on top of the stochasticity from sampling.

# %%
class CVAE(tf.keras.Model):
  """Convolutional variational autoencoder."""

  def __init__(self, latent_dim):
    super(CVAE, self).__init__()
    self.latent_dim = latent_dim
    self.encoder = tf.keras.Sequential(
        [
            tf.keras.layers.InputLayer(input_shape=(IMG_SIZE, IMG_SIZE, 3)),
            tf.keras.layers.Conv2D(
                filters=64, kernel_size=4, strides=(2, 2), activation='relu'),
            tf.keras.layers.Conv2D(
                filters=128, kernel_size=4, strides=(2, 2), activation='relu'),
         tf.keras.layers.Conv2D(
                filters=512, kernel_size=4, strides=(2, 2), activation='relu'),
            
        #   tf.keras.layers.Conv2D(
        #         filters=128, kernel_size=3, strides=(2, 2), activation='relu'),
            tf.keras.layers.Flatten(),
            # No activation
            tf.keras.layers.Dense(latent_dim + latent_dim),
        ]
    )

    self.decoder = tf.keras.Sequential(
        [
            tf.keras.layers.InputLayer(input_shape=(latent_dim,)),
            tf.keras.layers.Dense(units=16*16*32, activation=tf.nn.relu),
            tf.keras.layers.Reshape(target_shape=(16, 16, 32)),
          tf.keras.layers.Conv2DTranspose(
                filters=256, kernel_size=4, strides=2, padding='same',
                activation='relu'),
          # tf.keras.layers.Conv2DTranspose(
          #       filters=128, kernel_size=3, strides=2, padding='same',
          #       activation='relu'),
            tf.keras.layers.Conv2DTranspose(
                filters=64, kernel_size=4, strides=2, padding='same',
                activation='relu'),
            tf.keras.layers.Conv2DTranspose(
                filters=16, kernel_size=4, strides=2, padding='same',
                activation='relu'),
            # No activation
            tf.keras.layers.Conv2DTranspose(
                filters=3, kernel_size=4, strides=1, padding='same'),
        ]
    )

  @tf.function
  def sample(self, eps=None):
    if eps is None:
      eps = tf.random.normal(shape=(100, self.latent_dim))
    return self.decode(eps, apply_sigmoid=True)

  def encode(self, x):
    mean, logvar = tf.split(self.encoder(x), num_or_size_splits=2, axis=1)
    return mean, logvar

  def reparameterize(self, mean, logvar):
    eps = tf.random.normal(shape=mean.shape)
    return eps * tf.exp(logvar * .5) + mean

  def decode(self, z, apply_sigmoid=False):
    logits = self.decoder(z)
    if apply_sigmoid:
      probs = tf.sigmoid(logits)
      return probs
    return logits

# %% [markdown]
# ## Define the loss function and the optimizer
#
# VAEs train by maximizing the evidence lower bound (ELBO) on the marginal log-likelihood:
#
# $$\log p(x) \ge \text{ELBO} = \mathbb{E}_{q(z|x)}\left[\log \frac{p(x, z)}{q(z|x)}\right].$$
#
# In practice, optimize the single sample Monte Carlo estimate of this expectation:
#
# $$\log p(x| z) + \log p(z) - \log q(z|x),$$
# where $z$ is sampled from $q(z|x)$.
#
# Note: You could also analytically compute the KL term, but here you incorporate all three terms in the Monte Carlo estimator for simplicity.

# %%
optimizer = tf.keras.optimizers.Adam(1e-4)


def log_normal_pdf(sample, mean, logvar, raxis=1):
  log2pi = tf.math.log(2. * np.pi)
  return tf.reduce_sum(
      -.5 * ((sample - mean) ** 2. * tf.exp(-logvar) + logvar + log2pi),
      axis=raxis)


def compute_loss(model, x):
  mean, logvar = model.encode(x)
  z = model.reparameterize(mean, logvar)
  x_logit = model.decode(z)
  # reconstruction_term = -tf.reduce_sum(tfp.distributions.MultivariateNormalDiag(
  #   layers.Flatten()(x_logit), scale_identity_multiplier=0.05).log_prob(layers.Flatten()(x)))
  cross_ent = tf.nn.sigmoid_cross_entropy_with_logits(logits=x_logit, labels=x)
  # print( reconstruction_term)
  logpx_z = -tf.reduce_sum( cross_ent)
  # print(logpx_z) #Tensor("Neg:0", shape=(), dtype=float32)
  logpz = log_normal_pdf(z, 0., 0.)
  # print(logpz) 
  logqz_x = log_normal_pdf(z, mean, logvar)
  return -tf.reduce_mean( logpx_z  + logpz - logqz_x)


@tf.function
def train_step(model, x, optimizer):
  """Executes one training step and returns the loss.

  This function computes the loss and gradients, and uses the latter to
  update the model's parameters.
  """
  with tf.GradientTape() as tape:
    loss = compute_loss(model, x)
  gradients = tape.gradient(loss, model.trainable_variables)
  optimizer.apply_gradients(zip(gradients, model.trainable_variables))

# %% [markdown]
# ## Training
#
# * Start by iterating over the dataset
# * During each iteration, pass the image to the encoder to obtain a set of mean and log-variance parameters of the approximate posterior $q(z|x)$
# * then apply the *reparameterization trick* to sample from $q(z|x)$
# * Finally, pass the reparameterized samples to the decoder to obtain the logits of the generative distribution $p(x|z)$
# * Note: Since you use the dataset loaded by keras with 60k datapoints in the training set and 10k datapoints in the test set, our resulting ELBO on the test set is slightly higher than reported results in the literature which uses dynamic binarization of Larochelle's MNIST.
#
# ### Generating images
#
# * After training, it is time to generate some images
# * Start by sampling a set of latent vectors from the unit Gaussian prior distribution $p(z)$
# * The generator will then convert the latent sample $z$ to logits of the observation, giving a distribution $p(x|z)$
# * Here, plot the probabilities of Bernoulli distributions

# %%
epochs = 10
# set the dimensionality of the latent space to a plane for visualization later
latent_dim =512
num_examples_to_generate = 16

# keeping the random vector constant for generation (prediction) so
# it will be easier to see the improvement.
random_vector_for_generation = tf.random.normal(
    shape=[num_examples_to_generate, latent_dim])
model = CVAE(latent_dim)

# %%
def generate_and_save_images(model, epoch, test_sample):
  
  mean, logvar = model.encode(test_sample)
  z = model.reparameterize(mean, logvar)
  predictions = model.sample(z)
  fig = plt.figure(figsize=(4, 4))

  for i in range(predictions.shape[0]):
    plt.subplot(4, 4, i + 1)
    plt.imshow(predictions[i],cmap='gray')
    plt.axis('off')

  # tight_layout minimizes the overlap between 2 sub-plots
  plt.savefig('image_at_epoch_{:04d}.png'.format(epoch))
  plt.show()

# %%
# Pick a sample of the test set for generating output images
assert batch_size >= num_examples_to_generate
for test_batch in test_dataset.take(1):
  test_sample = test_batch[0:num_examples_to_generate, :, :, :]

# %%
generate_and_save_images(model, 0, test_sample)

for epoch in range(1, 40 + 1):
  start_time = time.time()
  for train_x in train_dataset:
    train_step(model, train_x, optimizer)
  end_time = time.time()

  loss = tf.keras.metrics.Mean()
  for test_x in test_dataset:
    loss(compute_loss(model, test_x))
  elbo = -loss.result()
  display.clear_output(wait=False)
  print('Epoch: {}, Test set ELBO: {}, time elapse for current epoch: {}'
        .format(epoch, elbo, end_time - start_time))
  generate_and_save_images(model, epoch, test_sample)
# Out:
# Epoch: 40, Test set ELBO: -880699.5, time elapse for current epoch: 13.195510149002075

# %% [markdown]
# ### Display a generated image from the last training epoch

# %%
def display_image(epoch_no):
  return PIL.Image.open('image_at_epoch_{:04d}.png'.format(epoch_no))

# %%
plt.imshow(display_image(epoch))
plt.axis('off')  # Display images
# Out:
# (-0.5, 287.5, 287.5, -0.5)

# %% [markdown]
# ### Display an animated GIF of all the saved images

# %%
anim_file = 'cvae.gif'

with imageio.get_writer(anim_file, mode='I') as writer:
  filenames = glob.glob('image*.png')
  filenames = sorted(filenames)
  for filename in filenames:
    image = imageio.imread(filename)
    writer.append_data(image)
  image = imageio.imread(filename)
  writer.append_data(image)

# %%
import tensorflow_docs.vis.embed as embed
embed.embed_file(anim_file)
# Out:
# <img src="data:image/gif;base64,..."/>

# %%
total_ssim=64
test_ssim = test_images[0:total_ssim, :, :, :]
mean, logvar = model.encode(test_ssim)
z = model.reparameterize(mean, logvar)
predictions = model.sample(z)
plt.imshow(test_ssim[0],cmap='gray')
plt.show()
plt.imshow(predictions[0],cmap='gray')

# %%
from skimage.measure import compare_ssim
score_sum=0
scores=[]
for i in range(0,total_ssim):
  (score, diff) = compare_ssim(np.array(test_ssim[i]), np.array(predictions[i]), full=True,multichannel=True)
  # diff = (diff * 255).astype("uint8")
  scores.append(score)
  score_sum+=score
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: DEPRECATED: skimage.measure.compare_ssim has been moved to skimage.metrics.structural_similarity. It will be removed from skimage.measure in version 0.18.
#   """

# %%
plt.plot(range(1,65),scores,)
plt.ylim(0, 1)
# Out:
# (0.0, 1.0)

# %%
score_sum/total_ssim
# Out:
# 0.6393821106775776

# %%
mse=0
mse_scores=[]
for i in range(0,total_ssim):
  Y = np.square(np.subtract(np.array(test_ssim[i]),np.array(predictions[i]))).mean()
  mse_scores.append(Y)
  mse+=Y

# %%
plt.plot(range(1,65),mse_scores)

# %%
mse/total_ssim
# Out:
# 0.0164821257640142

# %%
plt.imshow(test_ssim[0],cmap='gray')
plt.show()
plt.imshow(test_ssim[1],cmap='gray')

# %%
train_images[0:16].shape
# Out:
# (16, 128, 128, 3)

# %%
score,_=compare_ssim(np.array(test_ssim[0]),np.array(test_ssim[1]), full=True,multichannel=True)
print(score)
# Out:
# 0.28402303115617133
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: DEPRECATED: skimage.measure.compare_ssim has been moved to skimage.metrics.structural_similarity. It will be removed from skimage.measure in version 0.18.
#   """Entry point for launching an IPython kernel.

# %%
np.square(np.subtract(np.array(test_ssim[0]),np.array(test_ssim[1]))).mean()
# Out:
# 0.11637274

# %%
 fig = plt.figure(figsize=(4, 4))

for i in range(test_sample.shape[0]):
    plt.subplot(4, 4, i + 1)
    plt.imshow(test_sample[i,:,:,:],cmap='gray')
    plt.axis('off')

# %%
plt.imshow(train_images[0])

# %%
testz=np.random.rand(16,512)

# %%
testz=tf.convert_to_tensor(testz)

# %%
testz.shape
# Out:
# TensorShape([16, 512])

# %%
z.shape
# Out:
# TensorShape([16, 512])

# %%
plt.imshow(predictions[6],cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 127.5, 127.5, -0.5)

# %%
plt.imshow(test_sample[6],cmap='gray')
